# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import math
import shutil
import glob

# %%
# count the number of images in the respective classes 1-Brain Tumor 0-Healthy
ROOT_DIR="/content/drive/MyDrive/BrainTumorData/BrainTumorData"
number_of_images = {}

for dir in os.listdir(ROOT_DIR):
  number_of_images[dir]=len(os.listdir(os.path.join(ROOT_DIR,dir)))

number_of_images.items()
# Out:
# dict_items([('yes', 1518), ('no', 1500)])

# %% [markdown]
# # we will split the data such that
#   * 70 % for training
#   * 15 % for validation
#   * 15 % for testing

# %%
def dataFolder(p,split):  #p:path
  # we will create a train folder
  if not os.path.exists("./"+p):
     os.mkdir("./"+p)

     for dir in os.listdir(ROOT_DIR):
        os.makedirs("./"+p+"/"+dir)
        for img in np.random.choice(a=os.listdir(os.path.join(ROOT_DIR,dir)),
                                    size=(math.floor(split*number_of_images[dir])-5),
                                    replace=False ):
            O=os.path.join(ROOT_DIR,dir,img) # path # O: orginal path
            D=os.path.join("./"+p,dir) # path # D: Destination
            shutil.copy(O,D)
            #os.remove(O)
  else:
     print(f"the {p} folder exists ")

# %%
dataFolder("train",0.7)

# %%
dataFolder("dev",0.15)
dataFolder("test",0.15)

# %%
ROOT_DIR="/content/train"
number_of_train_image={}

for dir in os.listdir(ROOT_DIR):
  number_of_train_image[dir]=len(os.listdir(os.path.join(ROOT_DIR,dir)))

number_of_train_image.items()
# Out:
# dict_items([('yes', 1057), ('no', 1045)])

# %% [markdown]
# # Model Build

# %%
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, BatchNormalization, GlobalAvgPool2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras

# %%
# CNN Model

model = Sequential()

model.add(Conv2D(filters=64 , kernel_size=(3,3), activation='relu', input_shape=(224,224,3) )) # can ba add: padding='same'

model.add(Conv2D(filters=64 , kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2) ))

model.add(Conv2D(filters=64 , kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2) ))

model.add(Conv2D(filters=128 , kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2) ))

model.add(Dropout(rate=0.25) )

model.add(Flatten())
model.add(Dense(units=64, activation = 'relu'))
model.add(Dropout(rate=0.25) )
model.add(Dense(units=1, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 26, 26, 128)       0
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 64)                5537856
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5687425 (21.70 MB)
# Trainable params: 5687425 (21.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss=keras.losses.binary_crossentropy,metrics=['accuracy'])

# %%
from keras.applications.mobilenet import MobileNet, preprocess_input

def preprocessingImages1(path):
  """
  input : Path
  output: Pre processing images
  """
  #image_data=ImageDataGenerator(zoom_range=0.2,shear_range=0.2, rescale=1/255, horizontal_flip=True)
  image_data=ImageDataGenerator(zoom_range=0.2,shear_range=0.2, preprocessing_function=preprocess_input, horizontal_flip=True) # for transformer learning

  image=image_data.flow_from_directory(directory=path, target_size=(224,224), batch_size=64, class_mode='binary')

  return image

# %%
path="/content/train"
train_data=preprocessingImages1(path)
# Out:
# Found 2102 images belonging to 2 classes.

# %%
def preprocessingImages2(path):
  """
  input : Path
  output: Pre processing
  """
  #image_data=ImageDataGenerator(rescale=1/255)
  image_data=ImageDataGenerator(preprocessing_function=preprocess_input) # for transformer learning
  image=image_data.flow_from_directory(directory=path, target_size=(224,224), batch_size=64, class_mode='binary')

  return image

# %%
path="/content/test"
test_data=preprocessingImages2(path)
# Out:
# Found 442 images belonging to 2 classes.

# %%
path="/content/dev"
val_data=preprocessingImages2(path)
# Out:
# Found 442 images belonging to 2 classes.

# %%
# Early stopping and model check point

from keras.callbacks import ModelCheckpoint, EarlyStopping

# Eaarly stoppping

es=EarlyStopping(monitor='val_accuracy', min_delta=0.01, patience=5, verbose=1, mode='auto')

# model check point
mc=ModelCheckpoint(monitor='val_accuracy', filepath="./bestmodel.h5", verbose=1,save_best_only=True, mode='auto')

cd=[es,mc]

# %% [markdown]
# # Model Training

# %%
hs = model.fit_generator(generator=train_data,
                         steps_per_epoch=4,
                         epochs=30,
                         verbose=1,
                         validation_data=val_data,
                         validation_steps=7,
                         callbacks=cd )
# Out:
# Epoch 1/30
# 4/4 [==============================] - ETA: 0s - loss: 1.5133 - accuracy: 0.5117
# Epoch 1: val_accuracy improved from -inf to 0.49774, saving model to ./bestmodel.h5
# 4/4 [==============================] - 33s 5s/step - loss: 1.5133 - accuracy: 0.5117 - val_loss: 0.8127 - val_accuracy: 0.4977
# Epoch 2/30
# 4/4 [==============================] - ETA: 0s - loss: 0.7291 - accuracy: 0.5366
# Epoch 2: val_accuracy improved from 0.49774 to 0.73529, saving model to ./bestmodel.h5
# 4/4 [==============================] - 16s 5s/step - loss: 0.7291 - accuracy: 0.5366 - val_loss: 0.6487 - val_accuracy: 0.7353
# Epoch 3/30
# 4/4 [==============================] - ETA: 0s - loss: 0.6527 - accuracy: 0.6328
# Epoch 3: val_accuracy did not improve from 0.73529
# 4/4 [==============================] - 8s 2s/step - loss: 0.6527 - accuracy: 0.6328 - val_loss: 0.5865 - val_accuracy: 0.6674
# Epoch 4/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.6875
# Epoch 4: val_accuracy did not improve from 0.73529
# 4/4 [==============================] - 7s 2s/step - loss: 0.5940 - accuracy: 0.6875 - val_loss: 0.5470 - val_accuracy: 0.6968
# Epoch 5/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5806 - accuracy: 0.7276
# Epoch 5: val_accuracy improved from 0.73529 to 0.73982, saving model to ./bestmodel.h5
# 4/4 [==============================] - 7s 2s/step - loss: 0.5806 - accuracy: 0.7276 - val_loss: 0.5585 - val_accuracy: 0.7398
# Epoch 6/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5638 - accuracy: 0.6914
# Epoch 6: val_accuracy improved from 0.73982 to 0.77149, saving model to ./bestmodel.h5
# 4/4 [==============================] - 8s 2s/step - loss: 0.5638 - accuracy: 0.6914 - val_loss: 0.5207 - val_accuracy: 0.7715
# Epoch 7/30
# 4/4 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.6748
# Epoch 7: val_accuracy improved from 0.77149 to 0.78507, saving model to ./bestmodel.h5
# 4/4 [==============================] - 9s 3s/step - loss: 0.6146 - accuracy: 0.6748 - val_loss: 0.5111 - val_accuracy: 0.7851
# Epoch 8/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5527 - accuracy: 0.7148
# Epoch 8: val_accuracy did not improve from 0.78507
# 4/4 [==============================] - 6s 2s/step - loss: 0.5527 - accuracy: 0.7148 - val_loss: 0.4933 - val_accuracy: 0.7805
# Epoch 9/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5977 - accuracy: 0.6758
# Epoch 9: val_accuracy did not improve from 0.78507
# 4/4 [==============================] - 7s 2s/step - loss: 0.5977 - accuracy: 0.6758 - val_loss: 0.5034 - val_accuracy: 0.7851
# Epoch 10/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5703 - accuracy: 0.7422
# Epoch 10: val_accuracy did not improve from 0.78507
# 4/4 [==============================] - 7s 2s/step - loss: 0.5703 - accuracy: 0.7422 - val_loss: 0.4907 - val_accuracy: 0.7805
# Epoch 11/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5202 - accuracy: 0.7656
# Epoch 11: val_accuracy improved from 0.78507 to 0.78733, saving model to ./bestmodel.h5
# 4/4 [==============================] - 6s 2s/step - loss: 0.5202 - accuracy: 0.7656 - val_loss: 0.4586 - val_accuracy: 0.7873
# Epoch 12/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5856 - accuracy: 0.7148
# Epoch 12: val_accuracy improved from 0.78733 to 0.82353, saving model to ./bestmodel.h5
# 4/4 [==============================] - 7s 2s/step - loss: 0.5856 - accuracy: 0.7148 - val_loss: 0.4504 - val_accuracy: 0.8235
# Epoch 13/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5273 - accuracy: 0.7734
# Epoch 13: val_accuracy did not improve from 0.82353
# 4/4 [==============================] - 7s 2s/step - loss: 0.5273 - accuracy: 0.7734 - val_loss: 0.4503 - val_accuracy: 0.7964
# Epoch 14/30
# 4/4 [==============================] - ETA: 0s - loss: 0.4977 - accuracy: 0.7344
# Epoch 14: val_accuracy did not improve from 0.82353
# 4/4 [==============================] - 8s 2s/step - loss: 0.4977 - accuracy: 0.7344 - val_loss: 0.4145 - val_accuracy: 0.8167
# Epoch 15/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5481 - accuracy: 0.7266
# Epoch 15: val_accuracy did not improve from 0.82353
# 4/4 [==============================] - 7s 2s/step - loss: 0.5481 - accuracy: 0.7266 - val_loss: 0.4314 - val_accuracy: 0.8100
# Epoch 16/30
# 4/4 [==============================] - ETA: 0s - loss: 0.4624 - accuracy: 0.7734
# Epoch 16: val_accuracy improved from 0.82353 to 0.82805, saving model to ./bestmodel.h5
# 4/4 [==============================] - 7s 2s/step - loss: 0.4624 - accuracy: 0.7734 - val_loss: 0.4119 - val_accuracy: 0.8281
# Epoch 17/30
# 4/4 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.7891
# Epoch 17: val_accuracy improved from 0.82805 to 0.83710, saving model to ./bestmodel.h5
# 4/4 [==============================] - 8s 2s/step - loss: 0.4777 - accuracy: 0.7891 - val_loss: 0.3622 - val_accuracy: 0.8371
# Epoch 18/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.7188
# Epoch 18: val_accuracy did not improve from 0.83710
# 4/4 [==============================] - 7s 2s/step - loss: 0.5363 - accuracy: 0.7188 - val_loss: 0.4932 - val_accuracy: 0.7670
# Epoch 19/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5130 - accuracy: 0.7188
# Epoch 19: val_accuracy did not improve from 0.83710
# 4/4 [==============================] - 7s 2s/step - loss: 0.5130 - accuracy: 0.7188 - val_loss: 0.4647 - val_accuracy: 0.7986
# Epoch 20/30
# 4/4 [==============================] - ETA: 0s - loss: 0.4548 - accuracy: 0.8086
# Epoch 20: val_accuracy did not improve from 0.83710
# 4/4 [==============================] - 7s 2s/step - loss: 0.4548 - accuracy: 0.8086 - val_loss: 0.3694 - val_accuracy: 0.8258
# Epoch 21/30
# 4/4 [==============================] - ETA: 0s - loss: 0.4813 - accuracy: 0.7500
# Epoch 21: val_accuracy did not improve from 0.83710
# 4/4 [==============================] - 7s 2s/step - loss: 0.4813 - accuracy: 0.7500 - val_loss: 0.3739 - val_accuracy: 0.8190
# Epoch 22/30
# 4/4 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.7461
# Epoch 22: val_accuracy did not improve from 0.83710
# 4/4 [==============================] - 8s 2s/step - loss: 0.5272 - accuracy: 0.7461 - val_loss: 0.3900 - val_accuracy: 0.8303
# Epoch 22: early stopping

# %%
 # chnage the patinece to 5 and run it again it'll improve

# %%
# Model Graphical Interpretation
h=hs.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'], c="red")

plt.title("acc vs val-acc")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(h['loss'])
plt.plot(h['val_loss'], c="red")

plt.title("loss vs val-loss")
plt.show()

# %%
# Model Accuracy
from keras.models import load_model

model=load_model("/content/bestmodel.h5")

# %% [markdown]
# # Model Accuracy

# %%
acc=model.evaluate_generator(test_data)[1]
print(f"the accuracy of our model is {acc *100} %")
# Out:
# the accuracy of our model is 83.48416090011597 %

# %%
from keras.preprocessing.image import load_img, img_to_array

path="/content/drive/MyDrive/BrainTumorData/BrainTumorData/yes/y1002.jpg"

img=load_img(path, target_size=(224,224))

input_arr=img_to_array(img)/255

plt.imshow(input_arr)
plt.show()
input_arr.shape


input_arr=np.expand_dims(input_arr,axis=0)

pred=(model.predict(input_arr)[0][0]> 0.5).astype("int32")

pred

if pred==1:
  print("the MRI is having a tumor")
else:
  print("the MRI is not having a tumor")
# Out:
# 1/1 [==============================] - 1s 778ms/step
# the MRI is having a tumor

# %%
train_data.class_indices
# Out:
# {'no': 0, 'yes': 1}

# %% [markdown]
# # Transformer Learning for Tuning

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Flatten, Dense
from keras.models import Model, load_model
from keras.applications.mobilenet import MobileNet
import keras

# %%
base_model=MobileNet(input_shape=(224,224,3),include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable=False

# %%
X=Flatten()(base_model.output)
X=Dense(units=1, activation='sigmoid')(X)

model=Model(base_model.input,X)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 64)        256
#  zation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormali  (None, 56, 56, 128)       512
#  zation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D  (None, 56, 56, 128)       1152
#  )
#
#  conv_dw_3_bn (BatchNormali  (None, 56, 56, 128)       512
#  zation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormali  (None, 56, 56, 128)       512
#  zation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D  (None, 28, 28, 128)       1152
#  )
#
#  conv_dw_4_bn (BatchNormali  (None, 28, 28, 128)       512
#  zation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormali  (None, 28, 28, 256)       1024
#  zation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D  (None, 28, 28, 256)       2304
#  )
#
#  conv_dw_5_bn (BatchNormali  (None, 28, 28, 256)       1024
#  zation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormali  (None, 28, 28, 256)       1024
#  zation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D  (None, 14, 14, 256)       2304
#  )
#
#  conv_dw_6_bn (BatchNormali  (None, 14, 14, 256)       1024
#  zation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D  (None, 14, 14, 512)       4608
#  )
#
#  conv_dw_7_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D  (None, 14, 14, 512)       4608
#  )
#
#  conv_dw_8_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D  (None, 14, 14, 512)       4608
#  )
#
#  conv_dw_9_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2  (None, 14, 14, 512)       4608
#  D)
#
#  conv_dw_10_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2  (None, 14, 14, 512)       4608
#  D)
#
#  conv_dw_11_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D  (None, 15, 15, 512)       0
#  )
#
#  conv_dw_12 (DepthwiseConv2  (None, 7, 7, 512)         4608
#  D)
#
#  conv_dw_12_bn (BatchNormal  (None, 7, 7, 512)         2048
#  ization)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormal  (None, 7, 7, 1024)        4096
#  ization)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2  (None, 7, 7, 1024)        9216
#  D)
#
#  conv_dw_13_bn (BatchNormal  (None, 7, 7, 1024)        4096
#  ization)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormal  (None, 7, 7, 1024)        4096
#  ization)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_2 (Dense)             (None, 1)                 50177
#
# =================================================================
# Total params: 3279041 (12.51 MB)
# Trainable params: 50177 (196.00 KB)
# Non-trainable params: 3228864 (12.32 MB)
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss=keras.losses.binary_crossentropy,metrics=['accuracy'])

# %%
## Call Back
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Eaarly stoppping

es=EarlyStopping(monitor='accuracy', min_delta=0.01, patience=7, verbose=1)

# model check point
mc=ModelCheckpoint(monitor='accuracy', filepath="./bestmodel.h5", verbose=1,save_best_only=True)

cb=[mc,es]

# %%
hist = model.fit_generator(generator=train_data,
                         steps_per_epoch=8,
                         epochs=30,
                         verbose=1,
                         validation_data=val_data,
                         validation_steps=14,
                         callbacks=cb )
# Out:
# Epoch 1/30
# 8/8 [==============================] - ETA: 0s - loss: 1.1503 - accuracy: 0.8398
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 14 batches). You may need to use the repeat() function when building your dataset.
# Epoch 1: accuracy improved from -inf to 0.83984, saving model to ./bestmodel.h5
# 8/8 [==============================] - 9s 1s/step - loss: 1.1503 - accuracy: 0.8398 - val_loss: 0.3249 - val_accuracy: 0.9253
# Epoch 2/30
# 8/8 [==============================] - ETA: 0s - loss: 2.1496 - accuracy: 0.8066
# Epoch 2: accuracy did not improve from 0.83984
# 8/8 [==============================] - 7s 758ms/step - loss: 2.1496 - accuracy: 0.8066
# Epoch 3/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4836 - accuracy: 0.9316
# Epoch 3: accuracy improved from 0.83984 to 0.93164, saving model to ./bestmodel.h5
# 8/8 [==============================] - 8s 1s/step - loss: 0.4836 - accuracy: 0.9316
# Epoch 4/30
# 8/8 [==============================] - ETA: 0s - loss: 1.7108 - accuracy: 0.8418
# Epoch 4: accuracy did not improve from 0.93164
# 8/8 [==============================] - 7s 822ms/step - loss: 1.7108 - accuracy: 0.8418
# Epoch 5/30
# 8/8 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9512
# Epoch 5: accuracy improved from 0.93164 to 0.95117, saving model to ./bestmodel.h5
# 8/8 [==============================] - 7s 861ms/step - loss: 0.2746 - accuracy: 0.9512
# Epoch 6/30
# 8/8 [==============================] - ETA: 0s - loss: 2.2088 - accuracy: 0.8496
# Epoch 6: accuracy did not improve from 0.95117
# 8/8 [==============================] - 9s 894ms/step - loss: 2.2088 - accuracy: 0.8496
# Epoch 7/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5954 - accuracy: 0.9102
# Epoch 7: accuracy did not improve from 0.95117
# 8/8 [==============================] - 9s 1s/step - loss: 0.5954 - accuracy: 0.9102
# Epoch 8/30
# 8/8 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.9082
# Epoch 8: accuracy did not improve from 0.95117
# 8/8 [==============================] - 7s 888ms/step - loss: 0.4612 - accuracy: 0.9082
# Epoch 9/30
# 8/8 [==============================] - ETA: 0s - loss: 1.8599 - accuracy: 0.8340
# Epoch 9: accuracy did not improve from 0.95117
# 8/8 [==============================] - 6s 760ms/step - loss: 1.8599 - accuracy: 0.8340
# Epoch 10/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9766
# Epoch 10: accuracy improved from 0.95117 to 0.97656, saving model to ./bestmodel.h5
# 8/8 [==============================] - 6s 795ms/step - loss: 0.0839 - accuracy: 0.9766
# Epoch 11/30
# 8/8 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.9492
# Epoch 11: accuracy did not improve from 0.97656
# 8/8 [==============================] - 8s 981ms/step - loss: 0.2602 - accuracy: 0.9492
# Epoch 12/30
# 8/8 [==============================] - ETA: 0s - loss: 1.8674 - accuracy: 0.8068
# Epoch 12: accuracy did not improve from 0.97656
# 8/8 [==============================] - 6s 780ms/step - loss: 1.8674 - accuracy: 0.8068
# Epoch 13/30
# 8/8 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9766
# Epoch 13: accuracy did not improve from 0.97656
# 8/8 [==============================] - 7s 745ms/step - loss: 0.1079 - accuracy: 0.9766
# Epoch 14/30
# 8/8 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9746
# Epoch 14: accuracy did not improve from 0.97656
# 8/8 [==============================] - 8s 987ms/step - loss: 0.1570 - accuracy: 0.9746
# Epoch 15/30
# 8/8 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9629
# Epoch 15: accuracy did not improve from 0.97656
# 8/8 [==============================] - 7s 796ms/step - loss: 0.2083 - accuracy: 0.9629
# Epoch 16/30
# 8/8 [==============================] - ETA: 0s - loss: 2.0560 - accuracy: 0.8379
# Epoch 16: accuracy did not improve from 0.97656
# 8/8 [==============================] - 7s 768ms/step - loss: 2.0560 - accuracy: 0.8379
# Epoch 17/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9920
# Epoch 17: accuracy improved from 0.97656 to 0.99203, saving model to ./bestmodel.h5
# 8/8 [==============================] - 8s 1s/step - loss: 0.0331 - accuracy: 0.9920
# Epoch 18/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9900
# Epoch 18: accuracy did not improve from 0.99203
# 8/8 [==============================] - 6s 733ms/step - loss: 0.0434 - accuracy: 0.9900
# Epoch 19/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9844
# Epoch 19: accuracy did not improve from 0.99203
# 8/8 [==============================] - 7s 852ms/step - loss: 0.0839 - accuracy: 0.9844
# Epoch 20/30
# 8/8 [==============================] - ETA: 0s - loss: 1.5691 - accuracy: 0.8496
# Epoch 20: accuracy did not improve from 0.99203
# 8/8 [==============================] - 8s 995ms/step - loss: 1.5691 - accuracy: 0.8496
# Epoch 21/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9844
# Epoch 21: accuracy did not improve from 0.99203
# 8/8 [==============================] - 7s 816ms/step - loss: 0.0914 - accuracy: 0.9844
# Epoch 22/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9824
# Epoch 22: accuracy did not improve from 0.99203
# 8/8 [==============================] - 6s 768ms/step - loss: 0.0830 - accuracy: 0.9824
# Epoch 23/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9902
# Epoch 23: accuracy did not improve from 0.99203
# 8/8 [==============================] - 7s 802ms/step - loss: 0.0257 - accuracy: 0.9902
# Epoch 24/30
# 8/8 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9941
# Epoch 24: accuracy improved from 0.99203 to 0.99414, saving model to ./bestmodel.h5
# 8/8 [==============================] - 8s 1s/step - loss: 0.0180 - accuracy: 0.9941
# Epoch 24: early stopping

# %%
# Load the best fit model

model=load_model("/content/bestmodel.h5")

# %%
acc=model.evaluate_generator(test_data)[1]
print(f"the accuracy of our model is {acc *100} %")
# Out:
# the accuracy of our model is 99.09502267837524 %

# %%
h=hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'], c="green")

plt.title("accuracy")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(h['loss'])

plt.title("loss ")
plt.show()

# %%
from keras.preprocessing import image
path="/content/drive/MyDrive/BrainTumorData/BrainTumorData/yes/y1.jpg"

img=image.load_img(path, target_size=(224,224))

i=image.img_to_array(img)/255 # delet 255 and uncomment below command to see result
#i=preprocess_input(i)
input_arr=np.array([i])
input_arr.shape

pred=np.argmax(model.predict(input_arr))
pred

plt.imshow(input_arr[0])
plt.show()

if pred==0:
  print("the MRI is having a tumor")
else:
  print("the MRI is not having a tumor")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# the MRI is having a tumor
